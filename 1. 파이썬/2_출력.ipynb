# %%
print(999)
print(11,22,33,44)
# Out:
# 999
# 11 22 33 44

# %%
print(11,22,33,44,sep='*')
# Out:
# 11*22*33*44

# %%
# end 기본값은 줄바꿈, sep 기본값은 공백
print('Hello')
print('Python')
# Out:
# Hello
# Python

# %%
print('Hello', end='')
print('Python')
# Out:
# HelloPython

# %%
print('Hello',end=' ')
print('Python')
# Out:
# Hello Python

# %%
print("Hello\nPython!")
print("Name:\t김사과")
print("파이썬은 너무 재밌네: \\")
print("C:\\Users\\Administrator\\Documents")

# %%
print(10)
print(10 + 5)
print('덧셈: ', 10 + 5)
print('뺄셈: ', 10 - 5)
print('곱셈: ', 10 * 5)
print('나눗셈: ', 10 / 4)      # 실수 결과
print('정수 나눗셈: ', 10 // 4)   # 정수 몫
print('나머지: ', 10 % 4)         # 정수 나머지
print('거듭제곱: ', 10 ** 5)
# Out:
# 10
# 15
# 덧셈:  15
# 뺄셈:  5
# 곱셈:  50
# 나눗셈:  2.5
# 정수 나눗셈:  2
# 나머지:  1
# 거듭제곱:  100000

# %%
print('내친구: {} {}'.format('오렌지', '반하나'))
print("이름: {}, 나이: {}, 점수: {:.2f}".format('김사과', 20, 95.678))
print("첫 번째: {0}, 두 번째: {1}, 다시 첫 번째: {0}".format("사과", "오렌지"))
print("이름: {name}, 나이: {age}".format(name="김사과", age=20))
print("숫자: {:,}".format(1234567890))
print("16진수: {:x}, 8진수: {:o}, 2진수: {:b}".format(255, 255, 255))

# %%
print(f"10 + 20 = {10 + 20}")
print(f"3.14159를 소수 둘째자리까지 표현 {3.14159:.2f}")

# %%
a= 122 # 255
print(f"16진수: {a:04X}, 8진수: {a:o}, 2진수: {a:08b}")
print(f"16진수: {a:04x}, 8진수: {a:o}, 2진수: {a:08b}")
# Out:
# 16진수: 007A, 8진수: 172, 2진수: 01111010
# 16진수: 007a, 8진수: 172, 2진수: 01111010

# %%
# 대화식 실행에서는 연산 결과를 print 문 없이 확인 가능
20+50
# Out:
# 70

# %%
a=3
a
# Out:
# 3
